# %%
import torch
import tensor
import numpy as np

# %%
x = tensor.Tensor.from_numpy(np.array([1, 2, 3]), requires_grad=True)

# %%
y = x + 5
z = y + 10

# %%
z.requires_grad
# Out:
# True

# %%
z.backward()

# %%
x.grad
# Out:
# {'data': array([1, 1, 1]), 'requires_grad': False, 'is_leaf': True, 'grad_fn': None}
